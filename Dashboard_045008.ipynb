# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 49.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.125.2.111

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] / rollbackFailedOptional: verb npm-session 1137b2e180fbed6
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.2.111:8501
#
# npx: installed 22 in 4.419s
# your url is: https://shy-words-make.loca.lt
# 2024-01-17 07:21:14.078 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-01-17 07:21:41.706 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# /content/app.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## **Objective**
# The objective for the report based on the recruitment dashboard should be to analyze the recruitment process and candidate status, identify trends in candidate applications, evaluate the effectiveness of different recruitment stages and sources, and provide insights into the reasons for candidate declines and withdrawals. Additionally, the report should aim to assess the success rates of different companies and locations in the recruitment process.
#
# The primary goals include:
#
# **Process Analysis:**
#
# - Evaluate the efficiency of each stage in the recruitment process.
# Identify bottlenecks and areas for improvement in the workflow.
# Streamline the process for a more effective and timely recruitment cycle.
#
# **Trend Identification:**
#
# - Analyze trends in candidate applications over time.
# - Identify patterns in the volume and quality of applications.
# - Recognize seasonal or cyclical variations in recruitment activities.
#
# **Source Effectiveness:**
#
# - Evaluate the performance of different recruitment sources (e.g., job boards, referrals, social media).
# - Determine which sources yield the highest-quality candidates.
# - Optimize resource allocation based on the most effective channels.
#
# **Candidate Status Insights:**
#
# - Investigate reasons for candidate declines and withdrawals.
# - Provide insights into common trends or issues leading to candidate disengagement.
# - Implement strategies to enhance candidate experience and retention.
#
#
# ## **Data Overview:**
#
# - The dataset contains a total of 182 entries and 22 columns.
# The provided dataset encompasses comprehensive information on candidate applications and recruitment stages.
# It contains information about candidates, including their application details, recruitment stages, and status. Here are some initial observations from the dataset:
#
# - The dataset includes columns such as Comments, Fullname, Email, Phone_Number, Address, DoB (Date of Birth), Gender, Language, Source, Application_Date, Status, Recruitment_Stages, Company, Location, Decline_Reasons, Phone_Screen_Date, Harver_Test_Date, Interview_Date, Offer_Date, Hiring_Date, Payment_Date, and Modification_Date.
#
# - The "Status" column indicates the current status of the candidates, such as "On Hold", "Whitdraw", and "Rejected".
#
# - The "Recruitment_Stages" column represents the different stages of the recruitment process, including "Interview", "Phone Screening", and "Harver Test".
#
# - The "Decline_Reasons" column provides reasons for candidate decline, such as "Language level insufficient" and "Aceitou outra proposta" (Accepted another offer).

# %% [markdown]
# ##**Dashboard**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives**
#
# Objective 1: Evaluate Recruitment Metrics
#
# Analyze key recruitment metrics, including success rate, application per hire, and days to hire.
# Use gauge charts to visually compare and understand the efficiency of the recruitment process.
#
# Objective 2: Understand Application Data
#
# Examine application data, including demographics, application status, and recruitment stages.
# Identify patterns, trends, and potential areas for improvement.
#
# **Data Overview:**
#
# - The dataset includes information on applicants, recruitment stages, application status, and key dates.
# - Metrics such as success rate, application per hire, and days to hire are calculated for analysis.
# Analysis Approach:
#
# - Utilizing gauge charts to present key recruitment metrics in a visually impactful manner.
# - Segmenting data based on application status, recruitment stages, and key dates for deeper insights.
#
# **Observations:**
#
# - The dashboard provides a visual overview of recruitment metrics, application status, and demographic data.
#
# - Key Metrics:
# - Success Rate: 85.41%
# - Applications per Hire: 4.46
# - Days to Hire: 25 days
#
#
# - Demographic Insights: Analyzing gender, language, and location distribution among applicants.
#
# - Recruitment Stages:
# Visualizing the distribution of applicants across different recruitment stages.
#
# **Managerial Implications or Insights:**
#
# Efficiency of Recruitment Process:
# - The success rate of 85.41% indicates the effectiveness of the recruitment process.
# - Application per hire at 4.46 suggests a reasonable volume of applications per successful hire.
#
# Days to Hire:
#
# - A relatively short average of 25 days to hire showcases an efficient and streamlined recruitment process.
#
# Demographic Considerations:
#
# - Insights into gender, language, and location distribution can inform targeted recruitment strategies.
# - Identifying diversity and inclusion opportunities based on demographic data.
#
# Recruitment Stage Analysis:
#
# - Understanding the distribution of applicants across recruitment stages helps identify bottlenecks or areas of improvement.
# - Enhancing specific stages based on observations can optimize the overall recruitment process.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives**
#
# Objective 1: Evaluate Recruitment Efficiency
# Metric: Funnel Analysis
#
# Definition: Understand the progression of candidates through key recruitment stages.
#
# Analysis:
# - Utilize a funnel chart to visualize the conversion rates at each stage.
# Identify bottlenecks and areas of improvement in the recruitment process.
#
# Objective 2: Identify Key Metrics
#
# Metric 1: Conversion Rates
# Definition: Calculate the percentage of candidates moving from one stage to the next in the recruitment process.
#
# Analysis:
#
# - Identify conversion rates at each stage to pinpoint areas with high or low candidate drop-off.
# Determine the overall efficiency of the recruitment funnel.
#
# **Briefs on the Data & the Analysis**
#
# Data Overview:
# - The dataset includes candidate information at different stages of the recruitment process.
# - Key stages include Applied, Phone Screening, Harver Test, Interview, Offer, and Hired.
# - Metrics such as the number of candidates at each stage and conversion rates are calculated.
#
# **Observations**
#
# The funnel chart provides a visual representation of the candidate progression through the recruitment stages.
# Each section of the funnel represents a stage in the process, and the width of each section corresponds to the number of candidates at that stage.
#
# **Managerial Implications or Insights**
#
# Funnel Conversion Rates
#
# Applied to Phone Screening (Conversion: 98%)
#
# Insights:
# - A high conversion rate indicates an effective initial screening process.
# - Ensure that the screening process remains robust to maintain this high conversion rate.
#
# Phone Screening to Harver Test (Conversion: 66%)
#
# Insights:
# - A moderate drop in conversion may indicate challenges in the screening-to-test transition.
# - Investigate the screening criteria and test relevance to identify potential improvements.
#
# Harver Test to Interview (Conversion: 43%)
#
# Insights:
# - A significant drop suggests challenges in transitioning from the test to the interview stage.
# - Review the test and interview formats to ensure alignment with candidate skills.
#
# Interview to Offer (Conversion: 27%)
#
# Insights:
# - A notable drop at this stage may indicate challenges in aligning candidate expectations.
# - Assess the interview feedback and candidate expectations to improve alignment.
#
# Offer to Hired (Conversion: 22%)
#
# Insights:
# - A final drop signifies challenges in the negotiation or onboarding process.
# - Evaluate the offer presentation, negotiation process, and onboarding experience for enhancements.
#
# **Overall Recruitment Process**
#
# - The overall funnel chart highlights the need for continuous optimization in each stage.
#
# - Streamlining transitions, improving communication, and addressing candidate concerns can contribute to a more efficient recruitment process.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives**
#
# Utilize a donut chart to represent the percentage distribution of candidates at different stages in the recruitment pipeline.
# Identify the proportion of candidates progressing through Haver Test, Phone Screen, Interview, Offer, and Hire stages.
#
# **Briefs on the Data & the Analysis**
#
# - Data Overview
# The dataset includes information on the number and percentage of candidates at various stages in the recruitment process.
# Metrics provide insights into the distribution of candidates as they move through the recruitment stages.
# Analysis Tools
# Utilized data visualization tools to create a comprehensive dashboard with a donut chart representing the recruitment stages pipeline.
# The donut chart visually represents the percentage distribution of candidates at different recruitment stages.
#
# **Observations**
#
# Donut Chart: Recruitment Stages Pipeline
#
# - The donut chart visually represents the percentage distribution of candidates at different recruitment stages.
# Each segment of the donut corresponds to a recruitment stage, and the size indicates the percentage of candidates at that stage.
#
# - Haver Test:Candidates in the Haver Test stage represent 31% of the total.
#
# - Phone Screen: Candidates in the Phone Screen stage represent 17.2% of the total.
#
# - Interview: Candidates in the Interview stage represent 17.2% of the total.
#
# - Offer: Candidates in the Offer stage represent 17.2% of the total.
#
# - Hire: Candidates in the Hire stage represent 17.2% of the total.
#
# **Overall Analysis**
#
# The donut chart provides a clear visualization of the distribution of candidates across different recruitment stages.
# Insights from each stage can guide strategic decision-making, such as refining the evaluation process, optimizing communication, and streamlining the overall recruitment pipeline.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives**
#
# - Understand the progression of candidates through key recruitment stages.
#
# - Utilize a pie chart to visualize the distribution of hires from different sources.
# - Identify bottlenecks and areas of improvement in the recruitment process.
# - Calculate the percentage of candidates moving from one stage to the next in the recruitment process.
#
# - Identify conversion rates at each stage to pinpoint areas with high or low candidate drop-off. Determine the overall efficiency of the recruitment funnel.
# - Understand the distribution of hired candidates based on different recruitment sources.
#
# **Briefs on the Data & the Analysis**
#
# Data Overview: The dataset includes candidate information at different stages of the recruitment process.
# Metrics such as conversion rates through the funnel stages are calculated.
# A separate analysis is conducted to understand the distribution of hired candidates based on recruitment sources.
#
# **Observations**
#
# The pie chart displays the percentage of candidates hired from different recruitment sources.
# Each segment of the pie represents a source, and the size of the segment corresponds to the percentage of hires from that source.
#
# **Managerial Implications or Insights**
#
#
# Source-wise Hiring Distribution
#
# **Hired from ATS (29.5%)**
#
# Insights:
# ATS is the top source of hires, indicating the effectiveness of the Applicant Tracking System.
# Invest in optimizing and enhancing the ATS platform to maintain its positive impact.
#
# **Hired from Indeed (27.9%)**
#
# Insights:
# Indeed is a significant contributor to hires, showcasing its popularity among successful candidates.
# Continue leveraging Indeed and explore strategies to maximize its reach.
#
# **Hired from Linkedin (15.8%)**
#
# Insights:
# Linkedin is a valuable source, contributing to a considerable portion of hires.
# Explore targeted recruiting strategies on Linkedin to further enhance its effectiveness.
#
# **Hired from Glassdoor (12%)**
#
# Insights:
# Glassdoor plays a notable role in the recruitment process.
# Evaluate the company's presence on Glassdoor and consider initiatives to improve visibility.
#
# **Hired from Monster (6.56%)**
#
# Insights:
# Monster contributes to hiring but has a smaller share compared to other sources.
# Assess the ROI from Monster and consider adjustments to the recruitment strategy if needed.
#
# **Hired from CareerBuilder (4.37%)**
#
# Insights:
# CareerBuilder is a source with a moderate impact on hires.
# Explore ways to optimize the usage of CareerBuilder for better results.
#
# **Hired through Referral (3.83%)**
#
# Insights:
# Referrals contribute to the hiring process but have a relatively smaller share.
# Encourage and incentivize employee referrals to potentially increase this percentage.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives**
#
# - Assess the effectiveness of different recruitment sources in attracting and hiring qualified candidates.
#
# - Evaluate the percentage of applications and conversion rates for each source.
# - Identify areas of strength and potential improvements for each recruitment channel.
#
# **Briefs on the Data & the Analysis**
#
# Data Overview: The dataset includes information on the number of applications, percentage of applications, number of hires, percentage of hires, and conversion rates for various recruitment sources.
# Metrics provide insights into the performance of each source in the recruitment process.
#
# **Analysis Summary**
#
# The analysis focuses on understanding the recruitment performance of different sources based on the provided data frame.
#
# 1. ATS: ATS receives a significant number of applications, with almost 30% of all applications coming through this source.
# The conversion rate from application to hire is 20.37%, indicating the effectiveness of the ATS platform in attracting and selecting qualified candidates.
#
# 2. Indeed
#
# Insights:Indeed is a popular source, contributing to nearly 28% of total applications.
# The conversion rate from application to hire is 19.61%, showcasing the platform's ability to attract suitable candidates.
#
# 3. Linkedin
#
# Insights:Linkedin attracts around 16% of applications and maintains a conversion rate of 20.69%.
# The platform appears effective in both attracting applicants and successfully hiring candidates.
#
# 4. Glassdoor
#
#
# Insights:Glassdoor receives 12% of applications, and it boasts a high conversion rate of 22.73%.
# The platform appears to attract quality applicants, leading to a higher conversion rate.
#
# 5. CareerBuilder
#
# Insights:CareerBuilder, despite receiving a lower percentage of applications, has a remarkably high conversion rate of 41.67%.
# The platform is effective in attracting candidates who are likely to be successfully hired.
#
# 6. Monster
#
# Insights:Monster attracts a smaller percentage of applications but has the highest conversion rate of 50%.
# The platform seems to attract candidates who are highly likely to be hired.
#
# 7. Referral
#
# Insights:Referrals contribute to 3.83% of applications, but there are no hires recorded.
# Further investigation is needed to understand the reasons behind the lack of hires from this source.
#
# **Overall Analysis**
#
# - Application Distribution: ATS, Indeed, and Linkedin are the top three sources with the highest percentages of applications.
#
# - Conversion Rates: CareerBuilder, Monster, and Glassdoor have exceptionally high conversion rates, indicating their effectiveness in attracting and hiring qualified candidates.
#
# - Areas of Improvement: Referral, while contributing to applications, has not resulted in any hires. Consider strategies to optimize the referral process for better outcomes.
#
# - This analysis provides a detailed understanding of each recruitment source's performance, enabling informed decisions and optimizations in the recruitment strategy.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives**
#
# - Evaluate the distribution of declined applications based on different decline reasons.
#
#
# - Assess the number and percentage of applications declined for each reason.
# - Identify prevalent decline reasons and potential areas for improvement.
#
# **Briefs on the Data & the Analysis**
#
# Data Overview: The dataset includes information on the number and percentage of declined applications based on different decline reasons.
# Metrics provide insights into the distribution of declined applications across various decline reasons.
#
# **Analysis Summary**
#
# The analysis focuses on understanding the distribution of declined applications based on the provided data table.
#
# **Managerial Implications or Insights**
#
# 1. Language
# Language is the most common reason for application decline, constituting 43.48% of declined applications.
# Consider providing clear language proficiency expectations in job descriptions or communication to potential candidates.
#
# 2. Other
# The "Other" category is the second most prevalent reason for decline at 28.26%.
# Further investigation is needed to understand specific reasons falling under "Other" and address them accordingly.
#
# 3. Motivation
# Motivation accounts for 10.87% of declined applications.
# Evaluate whether motivation expectations align with job requirements and consider providing clearer guidance to applicants.
#
# 4. Profile
# Profile-related reasons contribute to 6.52% of declines.
# Ensure that job descriptions and application requirements are well-defined to attract candidates with suitable profiles.
#
# 5. Behaviour
# Behaviour-related issues result in 4.35% of declined applications.
# Consider providing detailed expectations on behavior during the application process or assessments.
#
# 6. Technical
# Technical reasons contribute to 4.35% of declines.
# Assess whether technical requirements are adequately communicated in job postings and consider providing additional guidance.
#
# 7. Experience
# Experience-related issues lead to a 2.17% decline rate.
# Clarify experience expectations in job descriptions and ensure they align with candidate qualifications.
#
# **Overall Analysis**
#
# This analysis sheds light on the distribution of declined applications based on different decline reasons, providing insights for optimizing the application and selection process.

# %% [markdown]
# ##**Managerial Implications**
#
#
#
# - Efficiency Improvement Opportunities:
#
# Insights: The Funnel Analysis reveals conversion rates at each recruitment stage.
# Managerial Implication: Managers should focus on optimizing stages with lower conversion rates. For instance, investigating the transition from Harver Test to Interview and improving alignment between interview formats and candidate skills can enhance efficiency.
#
# - Optimizing Recruitment Sources:
#
# Insights: The donut chart illustrates the percentage distribution of candidates at different stages.
# Managerial Implication: Understanding the distribution can guide resource allocation and strategy. If a particular source consistently provides candidates progressing further in the pipeline, consider investing more resources in that source.
#
# - Bottleneck Identification:
#
# Insights: The Funnel Analysis identifies stages with significant drops in conversion rates.
# Managerial Implication: Focus on stages with noticeable drops to identify bottlenecks. Improvements in screening criteria, test relevance, and interview alignment can address these bottlenecks and streamline the recruitment process.
#
# - Source Effectiveness for Hires:
#
# Insights: The Pie Chart visualizes the distribution of hired candidates from different sources.
# Managerial Implication: Evaluate the effectiveness of recruitment sources in terms of actual hires. Allocate resources to sources that consistently contribute to successful hires and consider refining strategies for less effective sources.
#
# - Diversity and Inclusion Strategies:
#
# Insights: Demographic data in the Overview and Donut Chart can inform diversity and inclusion efforts.
# Managerial Implication: Use demographic insights to develop targeted recruitment strategies. Ensure that the recruitment process addresses diversity goals and consider implementing initiatives to attract a more diverse pool of candidates.
#
# - Timely Decision-Making:
#
# Insights: The Gauge Charts present key metrics in a visually impactful manner.
# Managerial Implication: The use of gauge charts provides a quick overview of essential metrics, facilitating timely decision-making. Managers can swiftly identify areas that require attention and take immediate actions to improve recruitment processes.
#
# - Continuous Optimization:
#
# Insights: Overall, the dashboard emphasizes the need for continuous optimization.
# Managerial Implication: Recruitment is an ongoing process, and the dashboard highlights the importance of continuous improvement. Regularly review the data, implement feedback loops, and adapt strategies to evolving needs for sustained efficiency and effectiveness.

# %% [markdown]
# **Sources-**
#
# Codes and dataset-https://github.com/srdobolo/recruitment_dashboard/blob/main/Candidate_Sample_Set.csv
